# %%
import erppeek

odoo = erppeek.Client.from_config('odoo')

#TEST

emp=odoo.model('hr.employee')

# %%
emp.keys()
# Out:
# ['__last_update',
#  'active',
#  'activity_date_deadline',
#  'activity_exception_decoration',
#  'activity_exception_icon',
#  'activity_ids',
#  'activity_state',
#  'activity_summary',
#  'activity_type_icon',
#  'activity_type_id',
#  'activity_user_id',
#  'additional_note',
#  'address_home_id',
#  'address_id',
#  'applicant_id',
#  'badge_ids',
#  'bank_account_id',
#  'barcode',
#  'birthday',
#  'branch_id',
#  'calendar_mismatch',
#  'category_ids',
#  'certificate',
#  'child_all_count',
#  'child_ids',
#  'children',
#  'city_partner_id',
#  'coach_id',
#  'color',
#  'company_id',
#  'contract_id',
#  'contract_ids',
#  'contract_warning',
#  'contracts_count',
#  'country_id',
#  'country_of_birth',
#  'country_partner_id',
#  'create_date',
#  'create_uid',
#  'department_id',
#  'departure_date',
#  'departure_description',
#  'departure_reason',
#  'direct_badge_ids',
#  'display_name',
#  'document_ids',
#  'emergency_contact',
#  'emergency_contact_ids',
# ...

# %%
emp.fields()
# Out:
# {'company_id': {'type': 'many2one',
#   'change_default': False,
#   'company_dependent': False,
#   'context': {},
#   'depends': ['resource_id.company_id'],
#   'domain': [],
#   'manual': False,
#   'readonly': False,
#   'related': ['resource_id', 'company_id'],
#   'relation': 'res.company',
#   'required': True,
#   'searchable': True,
#   'sortable': True,
#   'store': True,
#   'string': 'Company'},
#  'is_address_home_a_company': {'type': 'boolean',
#   'change_default': False,
#   'company_dependent': False,
#   'depends': ['address_home_id.parent_id'],
#   'manual': False,
#   'readonly': True,
#   'required': False,
#   'searchable': False,
#   'sortable': False,
#   'store': False,
#   'string': 'The employee address has a company linked'},
#  'country_id': {'type': 'many2one',
#   'change_default': False,
#   'company_dependent': False,
#   'context': {},
#   'depends': [],
#   'domain': [],
#   'groups': 'hr.group_hr_user',
#   'manual': False,
#   'readonly': False,
# ...
