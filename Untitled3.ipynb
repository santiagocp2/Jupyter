# %%
import os
import odooly
import pandas as pd
from pandas_ods_reader import read_ods
from tqdm.notebook import tqdm

# %%
odooly.Client._config_file = os.path.expanduser('~/.config/odooly.ini')
odoo = odooly.Client.from_config('test2')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /tmp/ipykernel_30933/1338017668.py in <module>
#       1 odooly.Client._config_file = os.path.expanduser('~/.config/odooly.ini')
# ----> 2 odoo = odooly.Client.from_config('test2')
#
# ~/Documentos/Jupyter/venv/lib/python3.9/site-packages/odooly.py in from_config(cls, environment, user, verbose)
#     977         if user and user != conf_user:
#     978             password = None
# --> 979         client = cls(server, verbose=verbose)
#     980         client.env.name = environment
#     981         client.login(user or conf_user, password=password, database=db)
#
# ~/Documentos/Jupyter/venv/lib/python3.9/site-packages/odooly.py in __init__(self, server, db, user, password, transport, verbose)
#     910     def __init__(self, server, db=None, user=None, password=None,
#     911                  transport=None, verbose=False):
# ...
